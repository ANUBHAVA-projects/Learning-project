# %%
import pandas as pd
sonar_data=pd.read_csv("sonar.csv")
sonar_data
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
df_sonar=pd.DataFrame(sonar_data)
df_sonar
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
df_sonar.columns=range(0,61)
df_sonar
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
df_sonar.isnull().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
df_sonar.isna().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
#statistical observation
df_sonar.describe()
# Out:
#                0           1           2           3           4           5   \
# count  207.000000  207.000000  207.000000  207.000000  207.000000  207.000000
# mean     0.029208    0.038443    0.043837    0.054053    0.075105    0.104599
# std      0.023038    0.033040    0.038521    0.046583    0.055669    0.059247
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013300    0.016400    0.018900    0.024450    0.037700    0.066950
# 50%      0.022800    0.030800    0.034200    0.044100    0.062000    0.092100
# 75%      0.035800    0.048100    0.058200    0.065700    0.101050    0.134150
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  207.000000  207.000000  207.000000  207.000000  ...  207.000000
# mean     0.121591    0.134677    0.177361    0.208245  ...    0.016034
# ...

# %%
import numpy as np
from scipy.stats import zscore
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
df_sonar[60]=le.fit_transform(df_sonar[60])
df_sonar
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
# Checking of outliers
z=np.abs(zscore(df_sonar))
z
# Out:
# array([[0.70018948, 0.42042142, 1.0529498 , ..., 0.44268846, 0.42246083,
#         1.07529066],
#        [0.13089402, 0.59942737, 1.71912994, ..., 0.25299833, 0.25405324,
#         1.07529066],
#        [0.83579208, 0.64754631, 0.48045125, ..., 0.63683361, 1.03005467,
#         1.07529066],
#        ...,
#        [1.00042384, 0.15949749, 0.67235266, ..., 0.0382194 , 0.68112798,
#         0.92998111],
#        [0.0475061 , 0.09535845, 0.13434985, ..., 0.70154866, 0.34287094,
#         0.92998111],
#        [0.13959647, 0.06501846, 0.78685237, ..., 0.2970796 , 0.99025973,
#         0.92998111]])

# %%
np.where(z>3)
# Out:
# (array([  1,   1,   1,   1,   2,   2,   4,   4,  18,  18,  19,  20,  21,
#          21,  21,  21,  21,  21,  21,  21,  32,  43,  43,  43,  64,  84,
#          84,  86,  90,  90,  96,  96,  97,  97,  97,  97,  97,  97, 100,
#         100, 104, 110, 110, 110, 111, 126, 126, 126, 128, 128, 128, 130,
#         131, 131, 132, 132, 132, 133, 133, 133, 133, 134, 134, 134, 134,
#         135, 135, 135, 135, 136, 136, 137, 137, 137, 139, 139, 139, 139,
#         139, 140, 140, 141, 141, 141, 142, 142, 142, 143, 144, 144, 145,
#         145, 145, 145, 145, 145, 145, 145, 145, 146, 146, 146, 146, 146,
#         146, 146, 146, 160, 183, 185, 185, 185], dtype=int64),
#  array([ 8,  9, 11, 56, 38, 39, 13, 14,  4,  7,  5, 37, 38, 39, 40, 41, 46,
#         47, 48, 49, 49, 39, 42, 43, 58,  1,  2, 56,  5,  6, 58, 59,  0,  1,
#          2,  3,  4, 59, 12, 57, 55,  2,  3,  4, 57, 13, 54, 57,  0, 12, 53,
#          0,  7,  8,  8,  9, 52,  0,  6,  7,  8,  7,  8, 53, 55,  0,  7,  8,
# ...

# %%
df_sonar_new=df_sonar.loc[(z<3).all(axis=1)]
print(df_sonar.shape)
print(df_sonar_new.shape)
# Out:
# (207, 61)
# (167, 61)

# %%
df_sonar_new1=df_sonar_new.drop(60,axis=1)

# %%
df_sonar_new1.skew()
# Out:
# 0     1.252721
# 1     1.308041
# 2     1.653128
# 3     1.229816
# 4     0.933829
# 5     0.861935
# 6     0.359981
# 7     0.958050
# 8     0.978246
# 9     0.765877
# 10    0.750024
# 11    0.467539
# 12    0.684199
# 13    0.724465
# 14    0.712687
# 15    0.774311
# 16    0.667602
# 17    0.540145
# 18    0.251274
# 19   -0.087221
# 20   -0.282408
# 21   -0.512045
# 22   -0.648564
# 23   -0.687917
# 24   -1.063760
# 25   -1.052846
# 26   -0.955804
# 27   -0.854401
# 28   -0.573876
# 29   -0.140695
# 30    0.264920
# 31    0.335955
# 32    0.555980
# 33    0.706041
# 34    0.817889
# 35    0.807913
# 36    0.829148
# 37    0.917935
# 38    0.696745
# 39    0.716703
# 40    0.926007
# 41    0.687845
# 42    0.683889
# 43    1.250835
# 44    1.490031
# 45    0.990820
# 46    1.123128
# 47    0.893793
# 48    0.923176
# 49    0.936314
# 50    0.783265
# 51    1.258402
# 52    0.900249
# 53    0.861312
# 54    1.275296
# 55    0.768623
# 56    1.404770
# 57    1.371583
# ...

# %%
# Removing the skewness throgh boxcox function
from scipy.stats import boxcox
for col in df_sonar_new1.columns:
    if df_sonar_new1.skew().loc[col]>0.55:
        df_sonar_new1[col]=np.log1p(df_sonar_new1[col])

# %%
df_sonar_new1.skew()
# Out:
# 0     1.204038
# 1     1.231669
# 2     1.539889
# 3     1.125545
# 4     0.833268
# 5     0.722571
# 6     0.359981
# 7     0.748592
# 8     0.737412
# 9     0.518914
# 10    0.503509
# 11    0.467539
# 12    0.428228
# 13    0.430889
# 14    0.459186
# 15    0.552942
# 16    0.473461
# 17    0.540145
# 18    0.251274
# 19   -0.087221
# 20   -0.282408
# 21   -0.512045
# 22   -0.648564
# 23   -0.687917
# 24   -1.063760
# 25   -1.052846
# 26   -0.955804
# 27   -0.854401
# 28   -0.573876
# 29   -0.140695
# 30    0.264920
# 31    0.335955
# 32    0.270804
# 33    0.418022
# 34    0.560500
# 35    0.531996
# 36    0.545425
# 37    0.628615
# 38    0.491648
# 39    0.445296
# 40    0.625093
# 41    0.401422
# 42    0.413519
# 43    1.011251
# 44    1.241848
# 45    0.799454
# 46    0.946956
# 47    0.761163
# 48    0.855547
# 49    0.907990
# 50    0.760026
# 51    1.234090
# 52    0.886829
# 53    0.847440
# 54    1.259142
# 55    0.758770
# 56    1.388491
# 57    1.356364
# ...

# %%
df_sonar_new.isnull().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
df_sonar_new.isna().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
# Graphical represenation of the skewed data
df_sonar_new1[56].plot.hist()

# %%
df_sonar_new.corr()
sns.heatmap(df_sonar_new1.corr())

# %%
df_sonar_new1
# Out:
#            0         1         2         3         4         5       6   \
# 0    0.044304  0.050978  0.080935  0.066630  0.111810  0.229762  0.2156
# 3    0.073436  0.064476  0.046979  0.038644  0.057325  0.062881  0.1209
# 5    0.031208  0.091302  0.124074  0.131730  0.154779  0.157858  0.0731
# 6    0.050598  0.053351  0.080842  0.031402  0.109572  0.088194  0.1027
# 7    0.022055  0.036814  0.047265  0.046406  0.062693  0.057419  0.0753
# ..        ...       ...       ...       ...       ...       ...     ...
# 202  0.018527  0.034015  0.016660  0.017545  0.038547  0.151003  0.2028
# 203  0.031789  0.010049  0.029365  0.054867  0.073250  0.091485  0.0990
# 204  0.050883  0.042772  0.017840  0.028782  0.034498  0.110736  0.1257
# 205  0.029850  0.034691  0.047837  0.059023  0.016562  0.126985  0.1465
# 206  0.025668  0.035657  0.013508  0.026837  0.021174  0.033241  0.0655
#
#            7         8         9   ...        50        51        52  \
# ...

# %%
df_sonar_new.isnull().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
df_sonar_new1["rock/metal"]=df_sonar_new[60]
df_sonar_new1
# Out:
#             0         1         2         3         4         5       6  \
# 0    0.044304  0.050978  0.080935  0.066630  0.111810  0.229762  0.2156
# 3    0.073436  0.064476  0.046979  0.038644  0.057325  0.062881  0.1209
# 5    0.031208  0.091302  0.124074  0.131730  0.154779  0.157858  0.0731
# 6    0.050598  0.053351  0.080842  0.031402  0.109572  0.088194  0.1027
# 7    0.022055  0.036814  0.047265  0.046406  0.062693  0.057419  0.0753
# ..        ...       ...       ...       ...       ...       ...     ...
# 202  0.018527  0.034015  0.016660  0.017545  0.038547  0.151003  0.2028
# 203  0.031789  0.010049  0.029365  0.054867  0.073250  0.091485  0.0990
# 204  0.050883  0.042772  0.017840  0.028782  0.034498  0.110736  0.1257
# 205  0.029850  0.034691  0.047837  0.059023  0.016562  0.126985  0.1465
# 206  0.025668  0.035657  0.013508  0.026837  0.021174  0.033241  0.0655
#
#             7         8         9  ...        51        52        53  \
# ...

# %%
y=df_sonar_new1["rock/metal"]
y
# Out:
# 0      1
# 3      1
# 5      1
# 6      1
# 7      1
#       ..
# 202    0
# 203    0
# 204    0
# 205    0
# 206    0
# Name: rock/metal, Length: 167, dtype: int32

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.linear_model import LogisticRegression

# %%
def max_score(regr,x,y):
    max_accuracy_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr.fit(x_test,y_test)
        y_pred=regr.predict(x_test)
        acc_score=accuracy_score(y_test,y_pred)
        print("the accuracy score corresponsd to random state",r_state,"is",acc_score)
        print("confusion matrix",confusion_matrix(y_test,y_pred))
        print("classification_report",classification_report(y_test,y_pred))
        if acc_score>max_accuracy_score:
            max_accuracy_score=acc_score
            final_r_state=r_state
            
        print("the maximum accuracy score ",final_r_state,"is",max_accuracy_score)

# %%
lregr=LogisticRegression()
max_score(lregr,x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-f3e2a6e573c0> in <module>
#       1 lregr=LogisticRegression()
# ----> 2 max_score(lregr,x,y)
#
# NameError: name 'x' is not defined

# %% [raw]
# from sklearn.naive_bayes import MultinomialNB
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.model_selection import GridSearchCV
# neighbors={"n_neighbors":range(1,30)}
# Knr=KNeighborsClassifier()
# gknr=GridSearchCV(Knr,neighbors,cv=10)
# gknr.fit(x,y)
# gknr.best_params_

# %%
Knr=KNeighborsClassifier()
max_score(Knr,x,y)

# %%
# after analysis it is clear that Logistic regression is best model we can adopt
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.20)
lregr.fit(x_test,y_test)
y_pred=lregr.predict(x_test)
acc_score=accuracy_score(y_test,y_pred)
print("confusion matrix",confusion_matrix(y_test,y_pred))
print("classification_report",classification_report(y_test,y_pred))
            
print("the maximum accuracy score ",42,"is",acc_score)

# %%
# !pip install joblib

# %%
from joblib import dump
dump(lregr,"sonar_data_set.ipynb")
# Out:
# ['sonar_data_set.ipynb']
