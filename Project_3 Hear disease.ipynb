# %%
import pandas as pd

# %%
data=pd.read_csv("Heartdisease.csv",names=["age","sex","cp","trestbps","chol","fbs","restecg","thalach","exang","oldpeak","slope","ca","thal","target"],header=0)
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# age - the age of the persion
# sex - person's sex (1 - male, 0 - female)
# cp - type of the chest pain person suffered from (values 1-4)
# trestbps - resting blood pressure
# chol - serum cholestoral in mg/dl
# fbs - (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# restecg - resting electrocardiographic results
# thalach - person maximum heart rate
# exang - exercise induced angina (1 = yes; 0 = no)
# oldpeak - ST depression induced by exercise relative to rest
# slope - the slope of the peak exercise ST segment
# ca - number of major vessels (0-3) colored by flourosopy
# thal - blood disorder - thalassemia
# target - presence of heart disease (1 - yes, 0 - no)

# %%
df_Heartdisease=pd.DataFrame(data)
df_Heartdisease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df_Heartdisease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       199 non-null    int64
#  1   sex       199 non-null    int64
#  2   cp        199 non-null    int64
#  3   trestbps  199 non-null    object
#  4   chol      199 non-null    object
#  5   fbs       199 non-null    object
#  6   restecg   199 non-null    int64
#  7   thalach   199 non-null    object
#  8   exang     199 non-null    object
#  9   oldpeak   199 non-null    object
#  10  slope     199 non-null    object
#  11  ca        199 non-null    object
#  12  thal      199 non-null    object
#  13  target    199 non-null    int64
# dtypes: int64(5), object(9)
# memory usage: 21.9+ KB

# %%
df_Heartdisease.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df_Heartdisease.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
disease_number=len(df_Heartdisease[df_Heartdisease["target"]==1])
nodisease_number=len(df_Heartdisease[df_Heartdisease["target"]==0])
print("the no of person with disease :",disease_number)
print("the no of person with nodisease :",nodisease_number)
# Out:
# the no of person with disease : 165
# the no of person with nodisease : 138

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,4))
sns.countplot(x='target', data=df_Heartdisease)
plt.title('Number of patitents with and without a disease')
plt.xlabel('Target: 0 - no disease, 1 - disease')
# Out:
# Text(0.5, 0, 'Target: 0 - no disease, 1 - disease')

# %%
plt.figure(figsize=(8,6))
male = len(df_Heartdisease[df_Heartdisease['sex'] == 1])
female = len(df_Heartdisease[df_Heartdisease['sex'] == 0])
categories=[male, female]
labels = ['Male', 'Female']
plt.pie(categories, labels=labels, autopct="%1.1f%%", startangle=60)
plt.title('Sex distribution')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.countplot(x="target",hue="sex",data=df_Heartdisease)
plt.xlabel("0 - No Disease, 1 - Disease")
plt.legend(["male","female"])
plt.title("Disease distribution among sexes")
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(x="age",hue="target",data=df_Heartdisease)
plt.xlabel("age")
plt.legend(["nodisease","disease"])
plt.title("Disease distribution according to age")
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.countplot(x="cp",hue="target",data=df_Heartdisease)
plt.xlabel("Type of chest pain")
plt.legend(["nodisease","disease"])
plt.title("Disease distribution as per chest pain")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='age', y='trestbps', hue='target', data=df_Heartdisease)
plt.legend(['disease'])
plt.title('Resting Blood Pressure Distribution Among Ages')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='age', y='chol', hue='target', data=df_Heartdisease)
plt.legend(['disease'])
plt.title('Cholestrol level Among Ages')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from scipy.stats import zscore
import seaborn as sns
from scipy.stats import boxcox
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier

# %%
x=df_Heartdisease.iloc[:,0:-1]
x
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# ...

# %%
y=df_Heartdisease.target

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
lregr=LogisticRegression()
def maxraccuracy_score(regr,x,y):
    maxraccuracy_score=0
    for r_state in range(42,101):
        x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=r_state,test_size=0.20)
        scaler = StandardScaler()
        x_train = scaler.fit_transform(x_train)
        x_test = scaler.fit_transform(x_test)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        acc_scr=accuracy_score(y_test,y_pred)
        Class_rprt=classification_report(y_test,y_pred)
        conf_rprt=confusion_matrix(y_test,y_pred)
        print("classification report is",Class_rprt)
        print("confusion matrix is",conf_rprt)
        print("accuracy score correspond to random state",r_state,"is:", acc_scr)
        if acc_scr>maxraccuracy_score:
            maxraccuracy_score=acc_scr
            final_r_state=r_state
            
    print("max Accuracyscore corresponsds to ",final_r_state,"is:",maxraccuracy_score)
    return final_r_state

# %%
maxraccuracy_score(lregr,x,y)
# Out:
# classification report is               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88        29
#            1       0.88      0.91      0.89        32
#
#     accuracy                           0.89        61
#    macro avg       0.89      0.88      0.88        61
# weighted avg       0.89      0.89      0.89        61
#
# confusion matrix is [[25  4]
#  [ 3 29]]
# accuracy score correspond to random state 42 is: 0.8852459016393442
# classification report is               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91        28
#            1       0.89      0.97      0.93        33
#
#     accuracy                           0.92        61
#    macro avg       0.92      0.91      0.92        61
# weighted avg       0.92      0.92      0.92        61
#
# confusion matrix is [[24  4]
#  [ 1 32]]
# accuracy score correspond to random state 43 is: 0.9180327868852459
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=65,test_size=0.20)
from sklearn.model_selection import GridSearchCV
parameters={"n_neighbors":[5,10,15,20,25,30]}
gkcv=GridSearchCV(estimator=KNeighborsClassifier(),param_grid=parameters)
gkcv.fit(x_train,y_train)
print(gkcv.best_params_)
# Out:
# {'n_neighbors': 20}

# %%
Kregr=KNeighborsClassifier(n_neighbors=20)
maxraccuracy_score(Kregr,x,y)
# Out:
# classification report is               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86        29
#            1       0.85      0.91      0.88        32
#
#     accuracy                           0.87        61
#    macro avg       0.87      0.87      0.87        61
# weighted avg       0.87      0.87      0.87        61
#
# confusion matrix is [[24  5]
#  [ 3 29]]
# accuracy score correspond to random state 42 is: 0.8688524590163934
# classification report is               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89        28
#            1       0.89      0.94      0.91        33
#
#     accuracy                           0.90        61
#    macro avg       0.90      0.90      0.90        61
# weighted avg       0.90      0.90      0.90        61
#
# confusion matrix is [[24  4]
#  [ 2 31]]
# accuracy score correspond to random state 43 is: 0.9016393442622951
# ...

# %%
parameters={"kernel":["linear","poly","rbf"]}
gscv=GridSearchCV(estimator=SVC(),param_grid=parameters)
gscv.fit(x_train,y_train)
print(gscv.best_params_)
# Out:
# {'kernel': 'linear'}

# %%
sregr=SVC(kernel="linear")
maxraccuracy_score(sregr,x,y)
# Out:
# classification report is               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88        29
#            1       0.88      0.91      0.89        32
#
#     accuracy                           0.89        61
#    macro avg       0.89      0.88      0.88        61
# weighted avg       0.89      0.89      0.89        61
#
# confusion matrix is [[25  4]
#  [ 3 29]]
# accuracy score correspond to random state 42 is: 0.8852459016393442
# classification report is               precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85        28
#            1       0.84      0.94      0.89        33
#
#     accuracy                           0.87        61
#    macro avg       0.88      0.86      0.87        61
# weighted avg       0.87      0.87      0.87        61
#
# confusion matrix is [[22  6]
#  [ 2 31]]
# accuracy score correspond to random state 43 is: 0.8688524590163934
# ...

# %%
parameters={"criterion":["ginni","entropy"]}
gscv=GridSearchCV(estimator=DecisionTreeClassifier(),param_grid=parameters)
gscv.fit(x_train,y_train)
print(gscv.best_params_)

# %%
dregr=DecisionTreeClassifier(criterion="entropy")
maxraccuracy_score(dregr,x,y)
# Out:
# classification report is               precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84        29
#            1       0.89      0.78      0.83        32
#
#     accuracy                           0.84        61
#    macro avg       0.84      0.84      0.84        61
# weighted avg       0.84      0.84      0.84        61
#
# confusion matrix is [[26  3]
#  [ 7 25]]
# accuracy score correspond to random state 42 is: 0.8360655737704918
# classification report is               precision    recall  f1-score   support
#
#            0       0.85      0.79      0.81        28
#            1       0.83      0.88      0.85        33
#
#     accuracy                           0.84        61
#    macro avg       0.84      0.83      0.83        61
# weighted avg       0.84      0.84      0.84        61
#
# confusion matrix is [[22  6]
#  [ 4 29]]
# accuracy score correspond to random state 43 is: 0.8360655737704918
# ...

# %%
adregr=AdaBoostClassifier(n_estimators=50,base_estimator=lregr)
maxraccuracy_score(adregr,x,y)
# Out:
# classification report is               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88        29
#            1       0.88      0.91      0.89        32
#
#     accuracy                           0.89        61
#    macro avg       0.89      0.88      0.88        61
# weighted avg       0.89      0.89      0.89        61
#
# confusion matrix is [[25  4]
#  [ 3 29]]
# accuracy score correspond to random state 42 is: 0.8852459016393442
# classification report is               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91        28
#            1       0.89      0.97      0.93        33
#
#     accuracy                           0.92        61
#    macro avg       0.92      0.91      0.92        61
# weighted avg       0.92      0.92      0.92        61
#
# confusion matrix is [[24  4]
#  [ 1 32]]
# accuracy score correspond to random state 43 is: 0.9180327868852459
# ...

# %%
adregr=AdaBoostClassifier(n_estimators=50,base_estimator=dregr)
maxraccuracy_score(adregr,x,y)
# Out:
# classification report is               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.86        29
#            1       0.93      0.78      0.85        32
#
#     accuracy                           0.85        61
#    macro avg       0.86      0.86      0.85        61
# weighted avg       0.86      0.85      0.85        61
#
# confusion matrix is [[27  2]
#  [ 7 25]]
# accuracy score correspond to random state 42 is: 0.8524590163934426
# classification report is               precision    recall  f1-score   support
#
#            0       0.88      0.75      0.81        28
#            1       0.81      0.91      0.86        33
#
#     accuracy                           0.84        61
#    macro avg       0.84      0.83      0.83        61
# weighted avg       0.84      0.84      0.83        61
#
# confusion matrix is [[21  7]
#  [ 3 30]]
# accuracy score correspond to random state 43 is: 0.8360655737704918
# ...

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(lregr, x, y, cv=5)

scores
# Out:
# array([0.81967213, 0.8852459 , 0.83606557, 0.86666667, 0.76666667])

# %%
# Auc_Roc curve
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
y_pred_prob=lregr.predict_proba(x_test)[:,1]
y_pred_prob
# Out:
# array([4.35745278e-20, 3.32898247e-48, 1.59558320e-40, 1.07312964e-35,
#        2.37073115e-27, 1.34519705e-13, 2.44735428e-24, 8.17473017e-26,
#        3.58587098e-22, 5.93974189e-20, 2.15436759e-25, 2.64792365e-29,
#        2.71052488e-32, 1.02402708e-48, 1.54610987e-24, 2.47129975e-92,
#        7.39162553e-59, 2.92407943e-45, 3.62066363e-28, 7.28170433e-32,
#        2.14913580e-35, 2.44197219e-24, 1.20272408e-26, 2.40347886e-31,
#        2.91132575e-14, 2.15958392e-18, 4.55309896e-43, 1.37716627e-40,
#        3.07845174e-51, 6.78870368e-36, 3.58675469e-42, 1.85181261e-39,
#        2.82493183e-29, 8.27967061e-18, 1.55198578e-36, 2.07376911e-48,
#        2.33452037e-42, 1.79312464e-20, 1.32314317e-34, 1.10503403e-13,
#        6.00427681e-22, 1.33805424e-16, 2.81761798e-44, 8.81739643e-44,
#        2.85976349e-46, 1.83574575e-53, 3.68229835e-30, 7.95340387e-26,
#        5.99612478e-36, 1.14881331e-54, 1.31908282e-37, 4.97858231e-30,
# ...

# %%
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
fpr
# Out:
# array([0.        , 0.        , 0.        , 0.06896552, 0.06896552,
#        0.10344828, 0.10344828, 0.20689655, 0.20689655, 0.31034483,
#        0.31034483, 0.37931034, 0.37931034, 0.4137931 , 0.4137931 ,
#        0.51724138, 0.51724138, 0.5862069 , 0.5862069 , 0.62068966,
#        0.62068966, 0.65517241, 0.65517241, 1.        , 1.        ])

# %%
tpr
# Out:
# array([0.     , 0.03125, 0.15625, 0.15625, 0.53125, 0.53125, 0.59375,
#        0.59375, 0.625  , 0.625  , 0.6875 , 0.6875 , 0.78125, 0.78125,
#        0.8125 , 0.8125 , 0.84375, 0.84375, 0.875  , 0.875  , 0.90625,
#        0.90625, 0.96875, 0.96875, 1.     ])

# %%
plt.figure(figsize=(12,8))
plt.plot(fpr,tpr)
plt.xlabel("false positive rate")
plt.ylabel("true positive rate")
plt.title("Logistic Regression")
plt.show()

# %%
auc_score=roc_auc_score(y_test,y_pred_prob)
auc_score
# Out:
# 0.7672413793103448

# %%
#x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=65,test_size=0.20)

# From the analysis it is clear that Logistic Reression is the best classifier at random state 65 with a accuracy score of 93
# saving a file
import pickle
filename="picklelregr.pkl"
pickle.dump(LogisticRegression,open(filename,"wb"))
